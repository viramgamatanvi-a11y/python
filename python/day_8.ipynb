# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Handling categorical data

# %%
df=pd.DataFrame({
    'Color':['Red','Blue','Green','Red','Green']
})

# %%
df
# Out:
#    Color
# 0    Red
# 1   Blue
# 2  Green
# 3    Red
# 4  Green

# %%
df.dtypes
# Out:
# Color    object
# dtype: object

# %%
df['Color']=df['Color'].astype('category')

# %%
df
# Out:
#    Color
# 0    Red
# 1   Blue
# 2  Green
# 3    Red
# 4  Green

# %%
df.dtypes
# Out:
# Color    category
# dtype: object

# %%
sizes=pd.Categorical(['S','M','L','S','M','M','S','L'],categories=['S','M','L'],ordered=True)

sizes
# Out:
# ['S', 'M', 'L', 'S', 'M', 'M', 'S', 'L']
# Categories (3, object): ['S' < 'M' < 'L']

# %%
df_grades=pd.DataFrame({'Grade':['A','B','A','C','B','A']})

# %%
df_grades.value_counts()
# Out:
# Grade
# A        3
# B        2
# C        1
# Name: count, dtype: int64

# %%
df_grades['Grade']=df_grades['Grade'].astype('category')

# %%
df_grades.dtypes
# Out:
# Grade    category
# dtype: object

# %%
df_grades['Grade'].value_counts()
# Out:
# Grade
# A    3
# B    2
# C    1
# Name: count, dtype: int64

# %%
df=pd.DataFrame({
    'City':['Delhi','Mumbai','Delhi','Mumbai','Delhi'],
    'sales':[200,150,300,400,250]
})

# %%
df
# Out:
#      City  sales
# 0   Delhi    200
# 1  Mumbai    150
# 2   Delhi    300
# 3  Mumbai    400
# 4   Delhi    250

# %%
df=pd.DataFrame({
    'Sizes':['M','S','L','M'],
    "Item":['shirt','pants','shirt','cap']
})

# %%
df
# Out:
#   Sizes   Item
# 0     M  shirt
# 1     S  pants
# 2     L  shirt
# 3     M    cap

# %%
df['sizes']=pd.Categorical(df['Sizes'],categories=['S','M','L'],ordered=True)

# %%
df
# Out:
#   Sizes   Item sizes
# 0     M  shirt     M
# 1     S  pants     S
# 2     L  shirt     L
# 3     M    cap     M

# %%
df.sort_values (by='Sizes')
# Out:
#   Sizes   Item sizes
# 2     L  shirt     L
# 0     M  shirt     M
# 3     M    cap     M
# 1     S  pants     S

# %%
df
# Out:
#   Sizes   Item sizes
# 0     M  shirt     M
# 1     S  pants     S
# 2     L  shirt     L
# 3     M    cap     M

# %%
df['sizes']>'M'
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# Name: sizes, dtype: bool

# %%
df[df['sizes']>'M']
# Out:
#   Sizes   Item sizes
# 2     L  shirt     L

# %%
df['is_large']=df['sizes']>'M'

# %%
df
# Out:
#   Sizes   Item sizes  is_large
# 0     M  shirt     M     False
# 1     S  pants     S     False
# 2     L  shirt     L      True
# 3     M    cap     M     False

# %%
df[df['sizes']>'M']
# Out:
#   Sizes   Item sizes  is_large
# 2     L  shirt     L      True

# %%
df
# Out:
#   Sizes   Item sizes  is_large
# 0     M  shirt     M     False
# 1     S  pants     S     False
# 2     L  shirt     L      True
# 3     M    cap     M     False

# %%
df[df['sizes']>'M']
# Out:
#   Sizes   Item sizes  is_large
# 2     L  shirt     L      True

# %%
df[df['sizes']>'S']
# Out:
#   Sizes   Item sizes  is_large
# 0     M  shirt     M     False
# 2     L  shirt     L      True
# 3     M    cap     M     False

# %%
df[df['sizes']=='S']
# Out:
#   Sizes   Item sizes  is_large
# 1     S  pants     S     False

# %%
df
# Out:
#   Sizes   Item sizes  is_large
# 0     M  shirt     M     False
# 1     S  pants     S     False
# 2     L  shirt     L      True
# 3     M    cap     M     False

# %%
ndf=df['sizes'].cat.rename_categories({'S':'Small','M':'Medium','L':'Large'})

# %%
ndf
# Out:
# 0    Medium
# 1     Small
# 2     Large
# 3    Medium
# Name: sizes, dtype: category
# Categories (3, object): ['Small' < 'Medium' < 'Large']

# %%
employees=pd.DataFrame({
    'Name':['Alice','Bob','Charlie','David','Eve','Frank','Grace','Hannah','Ian','Jack',
            'Karen','Liam','Mona','Nina','Oscar'],
    'Gender':['Female','Male','Male','Male','Female','Male','Female','Female','Male','Male','Female','Male','Female','Female','Male'],
    'Age':[25,30,35,28,40,45,32,29,38,50,27,33,31,26,42],
    'Salary':[50000,60000,70000,55000,80000,90000,65000,58000,75000,10000,52000,67000,63000,54000,85000],
    'Role':['Engineer','Manager','Analyst','Engineer','Director','Manager','Analyst','Engineer','Director','Manager','Analyst','Engineer','Manager','Analyst','Director'],
})

employees
# Out:
#        Name  Gender  Age  Salary      Role
# 0     Alice  Female   25   50000  Engineer
# 1       Bob    Male   30   60000   Manager
# 2   Charlie    Male   35   70000   Analyst
# 3     David    Male   28   55000  Engineer
# 4       Eve  Female   40   80000  Director
# 5     Frank    Male   45   90000   Manager
# 6     Grace  Female   32   65000   Analyst
# 7    Hannah  Female   29   58000  Engineer
# 8       Ian    Male   38   75000  Director
# 9      Jack    Male   50   10000   Manager
# 10    Karen  Female   27   52000   Analyst
# 11     Liam    Male   33   67000  Engineer
# 12     Mona  Female   31   63000   Manager
# 13     Nina  Female   26   54000   Analyst
# 14    Oscar    Male   42   85000  Director

# %%
pd.get_dummies(employees, columns=['Gender'])
# Out:
#        Name  Age  Salary      Role  Gender_Female  Gender_Male
# 0     Alice   25   50000  Engineer           True        False
# 1       Bob   30   60000   Manager          False         True
# 2   Charlie   35   70000   Analyst          False         True
# 3     David   28   55000  Engineer          False         True
# 4       Eve   40   80000  Director           True        False
# 5     Frank   45   90000   Manager          False         True
# 6     Grace   32   65000   Analyst           True        False
# 7    Hannah   29   58000  Engineer           True        False
# 8       Ian   38   75000  Director          False         True
# 9      Jack   50   10000   Manager          False         True
# 10    Karen   27   52000   Analyst           True        False
# 11     Liam   33   67000  Engineer          False         True
# 12     Mona   31   63000   Manager           True        False
# 13     Nina   26   54000   Analyst           True        False
# 14    Oscar   42   85000  Director          False         True
