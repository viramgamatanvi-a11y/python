# %%
import pandas as pd

# %%
data=[10,20,30,40,50]
series=pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(data[0])
# Out:
# 10

# %%
print(data[2])
# Out:
# 30

# %%
print(data[0:4])
# Out:
# [10, 20, 30, 40]
